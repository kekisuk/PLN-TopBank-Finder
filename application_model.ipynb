# %%
import pandas as pd
import spacy
from collections import Counter
import re
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 import spacy
#       3 from collections import Counter
#       4 import re
#
# File c:\Users\kelen\OneDrive\Área de Trabalho\PNL TopBank Finder\.venv\Lib\site-packages\spacy\__init__.py:11
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
# ---> 11 from thinc.api import Config, prefer_gpu, require_cpu, require_gpu  # noqa: F401
#      13 from . import pipeline  # noqa: F401
#      14 from . import util
#
# File c:\Users\kelen\OneDrive\Área de Trabalho\PNL TopBank Finder\.venv\Lib\site-packages\thinc\api.py:1
# ----> 1 from .backends import (
#       2     CupyOps,
#       3     MPSOps,
#       4     NumpyOps,
#       5     Ops,
#       6     get_current_ops,
#       7     get_ops,
#       8     set_current_ops,
#       9     set_gpu_allocator,
#      10     use_ops,
#      11     use_pytorch_for_gpu_memory,
#      12     use_tensorflow_for_gpu_memory,
#      13 )
#      14 from .compat import enable_mxnet, enable_tensorflow, has_cupy
#      15 from .config import Config, ConfigValidationError, registry
#
# File c:\Users\kelen\OneDrive\Área de Trabalho\PNL TopBank Finder\.venv\Lib\site-packages\thinc\backends\__init__.py:17
#      15 from ._cupy_allocators import cupy_pytorch_allocator, cupy_tensorflow_allocator
#      16 from ._param_server import ParamServer
# ---> 17 from .cupy_ops import CupyOps
#      18 from .mps_ops import MPSOps
#      19 from .numpy_ops import NumpyOps
#
# File c:\Users\kelen\OneDrive\Área de Trabalho\PNL TopBank Finder\.venv\Lib\site-packages\thinc\backends\cupy_ops.py:16
#       6 from ..util import (
#       7     is_cupy_array,
#       8     is_mxnet_gpu_array,
#    (...)     13     torch2xp,
#      14 )
#      15 from . import _custom_kernels
# ---> 16 from .numpy_ops import NumpyOps
#      17 from .ops import Ops
#      20 @registry.ops("CupyOps")
#      21 class CupyOps(Ops):
#
# File c:\Users\kelen\OneDrive\Área de Trabalho\PNL TopBank Finder\.venv\Lib\site-packages\thinc\backends\numpy_ops.pyx:1, in init thinc.backends.numpy_ops()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %% [markdown]
# Leitura do Arquivo e Pré-processamento

# %%
# Carregar o modelo do spaCy para NLP
nlp = spacy.load("pt_core_news_sm")

# Leitura do arquivo CSV ou JSON com os posts
df_banks = pd.read_csv('database/posts_banks_structured.csv')

# %%
# Exemplo de pré-processamento de texto
def preprocess_text(text):
    # Remover caracteres especiais e números
    text = re.sub(r'[^a-zA-Záéíóúàâêîôûãõç\s]', '', text)
    
    # Tokenizar o texto e aplicar lematização
    doc = nlp(text.lower())  # Transformar o texto em minúsculas
    tokens = [token.lemma_ for token in doc if not token.is_stop]  # Remover stopwords e lematizar
    return tokens

# %%
# Pré-processar os textos dos posts
df_banks['tokens'] = df_banks['post'].apply(preprocess_text)
